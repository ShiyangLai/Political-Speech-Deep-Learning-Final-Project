# %%
import os.path

from mtcnn import MTCNN
import cv2

# %%
import matplotlib.pyplot as plt

# %%
count_faces = lambda x: len(detector.detect_faces(x))

# %%
img = cv2.cvtColor(cv2.imread("/Users/sudhamshu.hosamane/DataspellProjects/Political-Speech-Deep-Learning-Final-Project/dataset/images/1960-10-13_john_f._kennedy_debate_with_richard_nixon_in_new_york_and_los_angeles/246e557ab7.jpg"), cv2.COLOR_BGR2RGB)

# %%
img.shape
# Out:
# (529, 640, 3)

# %%
count_faces(img)
# Out:
# 2

# %%
plt.imshow(img)

# %%
detector = MTCNN()

# %%
img = cv2.cvtColor(cv2.imread("/Users/sudhamshu.hosamane/DataspellProjects/Political-Speech-Deep-Learning-Final-Project/dataset/images/1790-01-08_george_washington_first_annual_message_to_congress/c689001057.jpg"), cv2.COLOR_BGR2RGB)

# %%
img.shape
# Out:
# (760, 693, 3)

# %%
count_faces(img)
# Out:
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
#
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
#
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# ERROR! Session/line number was not unique inTraceback (most recent call last):
#   File "/Users/sudhamshu.hosamane/opt/anaconda3/envs/week-1/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 3457, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/var/folders/mx/f5d6vm016dx_8f4j5byy03nh0000gn/T/ipykernel_17285/3068137947.py", line 1, in <module>
#     count_faces(img)
#   File "/var/folders/mx/f5d6vm016dx_8f4j5byy03nh0000gn/T/ipykernel_17285/3498918506.py", line 1, in <lambda>
#     count_faces = lambda x: len(detector.detect_faces(x))
#   File "/Users/sudhamshu.hosamane/opt/anaconda3/envs/week-1/lib/python3.7/site-packages/mtcnn/mtcnn.py", line 287, in detect_faces
#     height, width, _ = img.shape
# ValueError: not enough values to unpack (expected 3, got 2)
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#    File "/Users/sudhamshu.hosamane/opt/anaconda3/envs/week-1/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 2077, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'ValueError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/sudhamshu.hosamane/opt/anaconda3/envs/week-1/lib/python3.7/site-packages/IPython/core/ultratb.py", line 1101, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "/Users/sudhamshu.hosamane/opt/anaconda3/envs/week-1/lib/python3.7/site-packages/IPython/core/ultratb.py", line 248, in wrapped
#     return f(*args, **kwargs)
#   File "/Users/sudhamshu.hosamane/opt/anaconda3/envs/week-1/lib/python3.7/site-packages/IPython/core/ultratb.py", line 281, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "/Users/sudhamshu.hosamane/opt/anaconda3/envs/week-1/lib/python3.7/inspect.py", line 1502, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "/Users/sudhamshu.hosamane/opt/anaconda3/envs/week-1/lib/python3.7/inspect.py", line 1460, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "/Users/sudhamshu.hosamane/opt/anaconda3/envs/week-1/lib/python3.7/inspect.py", line 696, in getsourcefile
#     if getattr(getmodule(object, filename), '__loader__', None) is not None:
# database. History logging moved to new session 491
#   File "/Users/sudhamshu.hosamane/opt/anaconda3/envs/week-1/lib/python3.7/inspect.py", line 733, in getmodule
#     if ismodule(module) and hasattr(module, '__file__'):
#   File "/Users/sudhamshu.hosamane/opt/anaconda3/envs/week-1/lib/python3.7/site-packages/tensorflow/__init__.py", line 50, in __getattr__
#     from ._api.v2 import bitwise
#   File "/Users/sudhamshu.hosamane/opt/anaconda3/envs/week-1/lib/python3.7/site-packages/tensorflow/__init__.py", line 44, in _load
#   File "/Users/sudhamshu.hosamane/opt/anaconda3/envs/week-1/lib/python3.7/importlib/__init__.py", line 127, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "<frozen importlib._bootstrap>", line 1006, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 983, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 965, in _find_and_load_unlocked
# ModuleNotFoundError: No module named 'tensorflow_core.estimator'
# Traceback (most recent call last):
#   File "/Users/sudhamshu.hosamane/opt/anaconda3/envs/week-1/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 3457, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/var/folders/mx/f5d6vm016dx_8f4j5byy03nh0000gn/T/ipykernel_17285/3068137947.py", line 1, in <module>
#     count_faces(img)
#   File "/var/folders/mx/f5d6vm016dx_8f4j5byy03nh0000gn/T/ipykernel_17285/3498918506.py", line 1, in <lambda>
#     count_faces = lambda x: len(detector.detect_faces(x))
#   File "/Users/sudhamshu.hosamane/opt/anaconda3/envs/week-1/lib/python3.7/site-packages/mtcnn/mtcnn.py", line 287, in detect_faces
#     height, width, _ = img.shape
# ValueError: not enough values to unpack (expected 3, got 2)
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/sudhamshu.hosamane/opt/anaconda3/envs/week-1/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 2077, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'ValueError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/sudhamshu.hosamane/opt/anaconda3/envs/week-1/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 3377, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "/Users/sudhamshu.hosamane/opt/anaconda3/envs/week-1/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 3474, in run_code
#     self.showtraceback(running_compiled_code=True)
#   File "/Users/sudhamshu.hosamane/opt/anaconda3/envs/week-1/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 2080, in showtraceback
#     value, tb, tb_offset=tb_offset)
#   File "/Users/sudhamshu.hosamane/opt/anaconda3/envs/week-1/lib/python3.7/site-packages/IPython/core/ultratb.py", line 1368, in structured_traceback
#     self, etype, value, tb, tb_offset, number_of_lines_of_context)
#   File "/Users/sudhamshu.hosamane/opt/anaconda3/envs/week-1/lib/python3.7/site-packages/IPython/core/ultratb.py", line 1268, in structured_traceback
#     self, etype, value, tb, tb_offset, number_of_lines_of_context
#   File "/Users/sudhamshu.hosamane/opt/anaconda3/envs/week-1/lib/python3.7/site-packages/IPython/core/ultratb.py", line 1125, in structured_traceback
#     tb_offset)
#   File "/Users/sudhamshu.hosamane/opt/anaconda3/envs/week-1/lib/python3.7/site-packages/IPython/core/ultratb.py", line 1082, in format_exception_as_a_whole
#     last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#   File "/Users/sudhamshu.hosamane/opt/anaconda3/envs/week-1/lib/python3.7/site-packages/IPython/core/ultratb.py", line 382, in find_recursion
#     return len(records), 0
# TypeError: object of type 'NoneType' has no len()
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/sudhamshu.hosamane/opt/anaconda3/envs/week-1/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 2077, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'TypeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/sudhamshu.hosamane/opt/anaconda3/envs/week-1/lib/python3.7/site-packages/IPython/core/ultratb.py", line 1101, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "/Users/sudhamshu.hosamane/opt/anaconda3/envs/week-1/lib/python3.7/site-packages/IPython/core/ultratb.py", line 248, in wrapped
#     return f(*args, **kwargs)
#   File "/Users/sudhamshu.hosamane/opt/anaconda3/envs/week-1/lib/python3.7/site-packages/IPython/core/ultratb.py", line 281, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "/Users/sudhamshu.hosamane/opt/anaconda3/envs/week-1/lib/python3.7/inspect.py", line 1502, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "/Users/sudhamshu.hosamane/opt/anaconda3/envs/week-1/lib/python3.7/inspect.py", line 1460, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "/Users/sudhamshu.hosamane/opt/anaconda3/envs/week-1/lib/python3.7/inspect.py", line 696, in getsourcefile
#     if getattr(getmodule(object, filename), '__loader__', None) is not None:
#   File "/Users/sudhamshu.hosamane/opt/anaconda3/envs/week-1/lib/python3.7/inspect.py", line 733, in getmodule
#     if ismodule(module) and hasattr(module, '__file__'):
#   File "/Users/sudhamshu.hosamane/opt/anaconda3/envs/week-1/lib/python3.7/site-packages/tensorflow/__init__.py", line 50, in __getattr__
#     from ._api.v2 import bitwise
#   File "/Users/sudhamshu.hosamane/opt/anaconda3/envs/week-1/lib/python3.7/site-packages/tensorflow/__init__.py", line 44, in _load
#   File "/Users/sudhamshu.hosamane/opt/anaconda3/envs/week-1/lib/python3.7/importlib/__init__.py", line 127, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "<frozen importlib._bootstrap>", line 1006, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 983, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 965, in _find_and_load_unlocked
# ModuleNotFoundError: No module named 'tensorflow_core.estimator'
# Traceback (most recent call last):
#   File "/Users/sudhamshu.hosamane/opt/anaconda3/envs/week-1/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 3457, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/var/folders/mx/f5d6vm016dx_8f4j5byy03nh0000gn/T/ipykernel_17285/3068137947.py", line 1, in <module>
#     count_faces(img)
#   File "/var/folders/mx/f5d6vm016dx_8f4j5byy03nh0000gn/T/ipykernel_17285/3498918506.py", line 1, in <lambda>
#     count_faces = lambda x: len(detector.detect_faces(x))
#   File "/Users/sudhamshu.hosamane/opt/anaconda3/envs/week-1/lib/python3.7/site-packages/mtcnn/mtcnn.py", line 287, in detect_faces
#     height, width, _ = img.shape
# ValueError: not enough values to unpack (expected 3, got 2)
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/sudhamshu.hosamane/opt/anaconda3/envs/week-1/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 2077, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'ValueError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/sudhamshu.hosamane/opt/anaconda3/envs/week-1/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 3377, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "/Users/sudhamshu.hosamane/opt/anaconda3/envs/week-1/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 3474, in run_code
#     self.showtraceback(running_compiled_code=True)
#   File "/Users/sudhamshu.hosamane/opt/anaconda3/envs/week-1/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 2080, in showtraceback
#     value, tb, tb_offset=tb_offset)
#   File "/Users/sudhamshu.hosamane/opt/anaconda3/envs/week-1/lib/python3.7/site-packages/IPython/core/ultratb.py", line 1368, in structured_traceback
#     self, etype, value, tb, tb_offset, number_of_lines_of_context)
#   File "/Users/sudhamshu.hosamane/opt/anaconda3/envs/week-1/lib/python3.7/site-packages/IPython/core/ultratb.py", line 1268, in structured_traceback
#     self, etype, value, tb, tb_offset, number_of_lines_of_context
#   File "/Users/sudhamshu.hosamane/opt/anaconda3/envs/week-1/lib/python3.7/site-packages/IPython/core/ultratb.py", line 1125, in structured_traceback
#     tb_offset)
#   File "/Users/sudhamshu.hosamane/opt/anaconda3/envs/week-1/lib/python3.7/site-packages/IPython/core/ultratb.py", line 1082, in format_exception_as_a_whole
#     last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#   File "/Users/sudhamshu.hosamane/opt/anaconda3/envs/week-1/lib/python3.7/site-packages/IPython/core/ultratb.py", line 382, in find_recursion
#     return len(records), 0
# TypeError: object of type 'NoneType' has no len()
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/sudhamshu.hosamane/opt/anaconda3/envs/week-1/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 2077, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'TypeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/sudhamshu.hosamane/opt/anaconda3/envs/week-1/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 2960, in _run_cell
#     return runner(coro)
#   File "/Users/sudhamshu.hosamane/opt/anaconda3/envs/week-1/lib/python3.7/site-packages/IPython/core/async_helpers.py", line 78, in _pseudo_sync_runner
#     coro.send(None)
#   File "/Users/sudhamshu.hosamane/opt/anaconda3/envs/week-1/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 3186, in run_cell_async
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "/Users/sudhamshu.hosamane/opt/anaconda3/envs/week-1/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 3396, in run_ast_nodes
#     self.showtraceback()
#   File "/Users/sudhamshu.hosamane/opt/anaconda3/envs/week-1/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 2080, in showtraceback
#     value, tb, tb_offset=tb_offset)
#   File "/Users/sudhamshu.hosamane/opt/anaconda3/envs/week-1/lib/python3.7/site-packages/IPython/core/ultratb.py", line 1368, in structured_traceback
#     self, etype, value, tb, tb_offset, number_of_lines_of_context)
#   File "/Users/sudhamshu.hosamane/opt/anaconda3/envs/week-1/lib/python3.7/site-packages/IPython/core/ultratb.py", line 1268, in structured_traceback
#     self, etype, value, tb, tb_offset, number_of_lines_of_context
#   File "/Users/sudhamshu.hosamane/opt/anaconda3/envs/week-1/lib/python3.7/site-packages/IPython/core/ultratb.py", line 1143, in structured_traceback
#     chained_exceptions_tb_offset)
#   File "/Users/sudhamshu.hosamane/opt/anaconda3/envs/week-1/lib/python3.7/site-packages/IPython/core/ultratb.py", line 1082, in format_exception_as_a_whole
#     last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#   File "/Users/sudhamshu.hosamane/opt/anaconda3/envs/week-1/lib/python3.7/site-packages/IPython/core/ultratb.py", line 382, in find_recursion
#     return len(records), 0
# TypeError: object of type 'NoneType' has no len()
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/sudhamshu.hosamane/opt/anaconda3/envs/week-1/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 2077, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'TypeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/sudhamshu.hosamane/opt/anaconda3/envs/week-1/lib/python3.7/site-packages/IPython/core/ultratb.py", line 1101, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "/Users/sudhamshu.hosamane/opt/anaconda3/envs/week-1/lib/python3.7/site-packages/IPython/core/ultratb.py", line 248, in wrapped
#     return f(*args, **kwargs)
#   File "/Users/sudhamshu.hosamane/opt/anaconda3/envs/week-1/lib/python3.7/site-packages/IPython/core/ultratb.py", line 281, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "/Users/sudhamshu.hosamane/opt/anaconda3/envs/week-1/lib/python3.7/inspect.py", line 1502, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "/Users/sudhamshu.hosamane/opt/anaconda3/envs/week-1/lib/python3.7/inspect.py", line 1460, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "/Users/sudhamshu.hosamane/opt/anaconda3/envs/week-1/lib/python3.7/inspect.py", line 696, in getsourcefile
#     if getattr(getmodule(object, filename), '__loader__', None) is not None:
#   File "/Users/sudhamshu.hosamane/opt/anaconda3/envs/week-1/lib/python3.7/inspect.py", line 733, in getmodule
#     if ismodule(module) and hasattr(module, '__file__'):
#   File "/Users/sudhamshu.hosamane/opt/anaconda3/envs/week-1/lib/python3.7/site-packages/tensorflow/__init__.py", line 50, in __getattr__
#     from ._api.v2 import bitwise
#   File "/Users/sudhamshu.hosamane/opt/anaconda3/envs/week-1/lib/python3.7/site-packages/tensorflow/__init__.py", line 44, in _load
#   File "/Users/sudhamshu.hosamane/opt/anaconda3/envs/week-1/lib/python3.7/importlib/__init__.py", line 127, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "<frozen importlib._bootstrap>", line 1006, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 983, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 965, in _find_and_load_unlocked
# ModuleNotFoundError: No module named 'tensorflow_core.estimator'

# %%
plt.imshow(img)

# %%
import shutil
import pandas as pd

# %%
DF = pd.read_csv('/Users/sudhamshu.hosamane/DataspellProjects/Political-Speech-Deep-Learning-Final-Project/dataset/presidential_speeches_manual_labels.csv')

# %%
DF
# Out:
#            Date          President         Party    Context  \
# 0    1789-04-30  George Washington  Unaffiliated  Inaugural
# 1    1789-10-03  George Washington  Unaffiliated       Misc
# 2    1790-01-08  George Washington  Unaffiliated   Congress
# 3    1790-12-08  George Washington  Unaffiliated   Congress
# 4    1790-12-29  George Washington  Unaffiliated     Native
# ..          ...                ...           ...        ...
# 987  2019-01-19       Donald Trump    Republican     Policy
# 988  2019-02-05       Donald Trump    Republican       SOTU
# 989  2019-02-15       Donald Trump    Republican     Policy
# 990  2019-09-24       Donald Trump    Republican         UN
# 991  2019-09-25       Donald Trump    Republican      Press
#
#                                           Speech Title  \
# 0                              First Inaugural Address
# 1                            Thanksgiving Proclamation
# 2                     First Annual Message to Congress
# 3                    Second Annual Message to Congress
# 4    Talk to the Chiefs and Counselors of the Senec...
# ..                                                 ...
# 987               Remarks about the US Southern Border
# 988                         State of the Union Address
# 989              Speech Declaring a National Emergency
# 990     Remarks at the United Nations General Assembly
# 991                                   Press Conference
#
#                                                Summary  \
# 0    Washington calls on Congress to avoid local an...
# 1    At the request of Congress, Washington establi...
# 2    In a wide ranging speech, President Washington...
# 3    Washington focuses on commerce in his second a...
# 4    The President reassures the Seneca Nation that...
# ..                                                 ...
# 987  President Donald Trump speaks about what he se...
# 988  In his second State of the Union Address, Pres...
# 989  President Donald Trump declares a national eme...
# 990  President Donald Trump speaks to the 74th sess...
# 991  President Donald Trump holds a press conferenc...
#
#                                             Transcript  \
# 0    Fellow Citizens of the Senate and the House of...
# 1    Whereas it is the duty of all Nations to ackno...
# 2    Fellow Citizens of the Senate and House of Rep...
# 3    Fellow citizens of the Senate and House of Rep...
# 4    I the President of the United States, by my ow...
# ..                                                 ...
# 987  Just a short time ago, I had the honor of pres...
# 988  Madam Speaker, Mr. Vice President, Members of ...
# 989  Thank you very much, everybody. Before we begi...
# 990  Thank you very much. Mr. President, Mr. Secret...
# 991  Thank you very much. Thank you. Well, thank yo...
#
#                                                    URL
# 0    https://millercenter.org/the-presidency/presid...
# 1    https://millercenter.org/the-presidency/presid...
# 2    https://millercenter.org/the-presidency/presid...
# 3    https://millercenter.org/the-presidency/presid...
# 4    https://millercenter.org/the-presidency/presid...
# ..                                                 ...
# 987  https://millercenter.org/the-presidency/presid...
# 988  https://millercenter.org/the-presidency/presid...
# 989  https://millercenter.org/the-presidency/presid...
# 990  https://millercenter.org/the-presidency/presid...
# 991  https://millercenter.org/the-presidency/presid...
#
# [992 rows x 8 columns]

# %%
DF.Context.value_counts()
# Out:
# Congress         154
# FP               139
# War              104
# SOTU              59
# Money             59
# Inaugural         57
# Policy            46
# Veto              44
# Convention        30
# Press             28
# University        26
# Commemoration     26
# Native            20
# Protest           19
# Campaign          18
# Tragedy           18
# Debate            13
# UN                13
# Farewell          10
# Scandal            8
# Proteest           1
# Wwar               1
# Campagin           1
# Name: Context, dtype: int64

# %%
DF = DF.fillna('Misc')

# %%
DF.Context.value_counts()
# Out:
# Congress         154
# FP               139
# War              104
# Misc              98
# SOTU              59
# Money             59
# Inaugural         57
# Policy            46
# Veto              44
# Convention        30
# Press             28
# University        26
# Commemoration     26
# Native            20
# Protest           19
# Campaign          18
# Tragedy           18
# Debate            13
# UN                13
# Farewell          10
# Scandal            8
# Proteest           1
# Wwar               1
# Campagin           1
# Name: Context, dtype: int64

# %%
DF[DF['Context']=='Misc']
# Out:
#            Date          President                  Party Context  \
# 1    1789-10-03  George Washington           Unaffiliated    Misc
# 22   1797-05-16         John Adams             Federalist    Misc
# 24   1798-03-23         John Adams             Federalist    Misc
# 31   1801-07-12   Thomas Jefferson  Democratic-Republican    Misc
# 33   1802-01-01   Thomas Jefferson  Democratic-Republican    Misc
# ..          ...                ...                    ...     ...
# 935  2010-02-09       Barack Obama             Democratic    Misc
# 942  2010-11-03       Barack Obama             Democratic    Misc
# 966  2014-11-20       Barack Obama             Democratic    Misc
# 976  2017-07-24       Donald Trump             Republican    Misc
# 978  2017-12-18       Donald Trump             Republican    Misc
#
#                                           Speech Title  \
# 1                            Thanksgiving Proclamation
# 22    Special Session Message to Congress (XYZ Affair)
# 24   Proclamation of Day of Fasting, Humiliation an...
# 31                 The Reply to New Haven Remonstrance
# 33             Response to Danbury Baptist Association
# ..                                                 ...
# 935          News Conference on Congressional Gridlock
# 942      Press Conference After 2010 Midterm Elections
# 966               Address to the Nation on Immigration
# 976                   Speech at the Boy Scout Jamboree
# 978              Remarks on National Security Strategy
#
#                                                Summary  \
# 1    At the request of Congress, Washington establi...
# 22   The President informs Congress of the diplomat...
# 24                                                Misc
# 31   After Jefferson removed the collector for the ...
# 33   Responding to a supportive letter from the Dan...
# ..                                                 ...
# 935  The president holds a news conference after me...
# 942  President Obama holds a press conference after...
# 966  President Obama delivers an address to the nat...
# 976  President Trump addresses the Boy Scout Jambor...
# 978  President Donald Trump addresses the issue of ...
#
#                                             Transcript  \
# 1    Whereas it is the duty of all Nations to ackno...
# 22   The personal inconveniences to the members of ...
# 24   As the safety and prosperity of nations ultima...
# 31   GENTLEMAN, I have received the remonstrance yo...
# 33   GENTLEMAN, The affectionate sentiments of este...
# ..                                                 ...
# 935  Hello, everybody. I am glad to see that all of...
# 942  Good afternoon, everybody. Last night I had a ...
# 966  My fellow Americans, tonight, I'd like to talk...
# 976  TRUMP: Thank you, everybody. Thank you very mu...
# 978  Thank you very much. Thank you. Please. I want...
#
#                                                    URL
# 1    https://millercenter.org/the-presidency/presid...
# 22   https://millercenter.org/the-presidency/presid...
# 24   https://millercenter.org/the-presidency/presid...
# 31   https://millercenter.org/the-presidency/presid...
# 33   https://millercenter.org/the-presidency/presid...
# ..                                                 ...
# 935  https://millercenter.org/the-presidency/presid...
# 942  https://millercenter.org/the-presidency/presid...
# 966  https://millercenter.org/the-presidency/presid...
# 976  https://millercenter.org/the-presidency/presid...
# 978  https://millercenter.org/the-presidency/presid...
#
# [98 rows x 8 columns]

# %%
import os
from os import listdir

# %%
for dir in listdir('/Users/sudhamshu.hosamane/Downloads/images'):
    print(dir)
    for file in listdir(os.path.join('/Users/sudhamshu.hosamane/Downloads/images',dir)):
        img = cv2.cvtColor(cv2.imread(os.path.join('/Users/sudhamshu'
                                              '.hosamane/Downloads/images',dir,file)), cv2.COLOR_BGR2RGB)
        cntxt = DF.loc[DF.Date==dir.split('_')[0]]['Context'].to_string().split()[1]
        os.makedirs('/Users/sudhamshu.hosamane/prez_img_datset/'+cntxt,
                    exist_ok=True)

        if count_faces(img) == 1:
            # pass
            shutil.copy(os.path.join('/Users/sudhamshu.hosamane/Downloads/images',dir,file),
                                    '/Users/sudhamshu.hosamane/prez_img_datset/'+cntxt +'/'+dir+'.jpg')
            break
        # print('\t', file, count_faces(img))
# Out:
# ERROR! Session/line number was not unique in database. History logging moved to new session
# 2013-09-10_barack_obama_address_to_the_nation_on_syria
# 1965-03-26_lyndon_b._johnson_statement_on_arrests_in_violo_liuzzo_murder
# 1977-01-20_jimmy_carter_inaugural_address
# 2013-03-01_barack_obama_statement_on_the_government_sequester
# 1972-11-06_richard_m._nixon_remarks_on_election_eve
# 1987-06-12_ronald_reagan_address_from_the_brandenburg_gate_(berlin_wall)
# 1964-10-18_lyndon_b._johnson_report_to_the_nation_on_events_in_china_and_the_ussr
# 1986-09-14_ronald_reagan_speech_to_the_nation_on_the_campaign_against_drug_abuse
# 1968-10-31_lyndon_b._johnson_remarks_on_the_cessation_of_bombing_of_north_vietnam
# 2006-01-31_george_w._bush_state_of_the_union_address
# 1990-10-01_george_h._w._bush_address_to_the_united_nations
# 1964-07-02_lyndon_b._johnson_remarks_upon_signing_the_civil_rights_bill
# 1965-06-25_lyndon_b._johnson_remarks_on_the_20th_anniversary_of_the_u.n._charter
# 1991-07-31_george_h._w._bush_press_conference_with_mikhail_gorbachev
# 1944-06-05_franklin_d._roosevelt_on_the_fall_of_rome
# 1944-01-11_franklin_d._roosevelt_on_the_state_of_the_union
# 1967-03-09_lyndon_b._johnson_press_conference
# 1967-02-02_lyndon_b._johnson_press_conference
# 1982-08-16_ronald_reagan_address_on_tax_and_budget_legislation
# 1940-05-26_franklin_d._roosevelt_on_national_defense

# %%
dir
# Out:
# '1940-05-26_franklin_d._roosevelt_on_national_defense'

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator, load_img

# %%
DF.loc[DF.Date==dir.split('_')[0]]['Context'].to_string().split()[1]
# Out:
# 'War'

# %%
plt.figure(figsize=(14,22))
i = 1
train_dir = '/Users/sudhamshu.hosamane/prez_img_datset/data/'
for expression in os.listdir(train_dir):
    print(expression)
    if not expression.startswith('.'):
        print(train_dir + expression +'/'+ os.listdir(train_dir+'/' + expression)[1])
        img = load_img((train_dir + expression +'/'+ os.listdir(train_dir+'/' + expression)[1]))
        # plt.subplot(1,7,i)
        plt.imshow(img)
        plt.title(expression)
        plt.axis('off')
        i += 1
plt.show()
# Out:
# Scandal
# /Users/sudhamshu.hosamane/prez_img_datset/data/Scandal/1974-08-08_richard_m._nixon_address_to_the_nation_announcing_decision_to_resign_the_office_of_president.jpg
# UN
# /Users/sudhamshu.hosamane/prez_img_datset/data/UN/1963-09-20_john_f._kennedy_address_to_the_un_general_assembly.jpg
# Tragedy
# /Users/sudhamshu.hosamane/prez_img_datset/data/Tragedy/2012-12-16_barack_obama_remarks_on_sandy_hook_elementary_shootings.jpg
# .DS_Store
# Commemoration
# /Users/sudhamshu.hosamane/prez_img_datset/data/Commemoration/1961-11-16_john_f._kennedy_university_of_washington_s_100th_anniversary.jpg
# Inaugural
# /Users/sudhamshu.hosamane/prez_img_datset/data/Inaugural/1941-01-20_franklin_d._roosevelt_third_inaugural_address.jpg
# FP
# /Users/sudhamshu.hosamane/prez_img_datset/data/FP/1962-10-22_john_f._kennedy_address_on_the_buildup_of_arms_in_cuba.jpg
# Press
# /Users/sudhamshu.hosamane/prez_img_datset/data/Press/1965-02-04_lyndon_b._johnson_press_conference.jpg
# University
# /Users/sudhamshu.hosamane/prez_img_datset/data/University/1963-06-10_john_f._kennedy_american_university_commencement.jpg
# Debate
# /Users/sudhamshu.hosamane/prez_img_datset/data/Debate/1996-10-06_bill_clinton_presidential_debate_with_senator_bob_dole.jpg
# Convention
# /Users/sudhamshu.hosamane/prez_img_datset/data/Convention/2004-09-03_george_w._bush_remarks_at_the_republican_national_convention.jpg
# Protest
# /Users/sudhamshu.hosamane/prez_img_datset/data/Protest/1943-05-02_franklin_d._roosevelt_on_the_coal_crisis.jpg
# Farewell
# /Users/sudhamshu.hosamane/prez_img_datset/data/Farewell/2009-01-15_george_w._bush_farewell_address_to_the_nation.jpg
# Money
# /Users/sudhamshu.hosamane/prez_img_datset/data/Money/1981-04-28_ronald_reagan_address_on_the_program_for_economic_recovery.jpg
# War
# /Users/sudhamshu.hosamane/prez_img_datset/data/War/1972-01-25_richard_m._nixon_address_to_the_nation_on_plan_for_peace_in_vietnam.jpg
# Campaign
# /Users/sudhamshu.hosamane/prez_img_datset/data/Campaign/2008-11-04_barack_obama_remarks_on_election_night.jpg
# SOTU
# /Users/sudhamshu.hosamane/prez_img_datset/data/SOTU/2006-01-31_george_w._bush_state_of_the_union_address.jpg
# Congress
# /Users/sudhamshu.hosamane/prez_img_datset/data/Congress/1963-11-27_lyndon_b._johnson_address_to_joint_session_of_congress.jpg
# Policy
# /Users/sudhamshu.hosamane/prez_img_datset/data/Policy/2001-01-29_george_w._bush_remarks_on_faith-based_and_community_initiatives.jpg

# %%
test_datagen = ImageDataGenerator(rescale=1./255)
test_set = test_datagen.flow_from_directory('/Users/sudhamshu.hosamane/prez_img_datset/data',
                                            batch_size=64,
                                            target_size=(48,48),
                                            shuffle=True,
                                            color_mode='grayscale',
                                            class_mode='categorical')
# Out:
# ERROR! Session/line number was not unique in database. History logging moved to new session 484
# Found 344 images belonging to 18 classes.

# %%
pixels = plt.imread('/Users/sudhamshu'
                    '.hosamane/prez_img_datset/data/Scandal/1998-08-17_bill_clinton_statement_on_his_testimony_before_the_grand_jury.jpg')
# Out:
# ERROR! Session/line number was not unique in database. History logging moved to new session 490

# %%
from PIL import Image
img = cv2.cvtColor(cv2.imread('/Users/sudhamshu.hosamane/prez_img_datset/data/UN/2002-09-12_george_w'
                              '._bush_remarks_at_the_un_general_assembly.jpg'), cv2.COLOR_BGR2RGB)
plt.imshow(img, cmap='gray')

# %%
plt.imshow(img, cmap='gray')

# %%
faces = detector.detect_faces(img)

# %%
print(faces)
# Out:
# [{'box': [334, 58, 89, 131], 'confidence': 0.9994334578514099, 'keypoints': {'left_eye': (351, 108), 'right_eye': (389, 111), 'nose': (363, 133), 'mouth_left': (351, 157), 'mouth_right': (383, 159)}}]

# %%
plt.imshow(img[58:(58+131), 334:(334+89) ])

# %%
img.shape
# Out:
# (600, 796, 3)

# %%
from matplotlib.patches import Rectangle
def highlight_faces(image_path, faces):
    # display image
    image = plt.imread(image_path)
    plt.imshow(image)

    ax = plt.gca()

    # for each face, draw a rectangle based on coordinates
    for face in faces:
        x, y, width, height = face['box']
        face_border = Rectangle((x, y), width, height,
                                fill=False, color='red')
        ax.add_patch(face_border)
    plt.show()

# %%
highlight_faces('/Users/sudhamshu.hosamane/prez_img_datset/data/UN/2002-09-12_george_w'
                '._bush_remarks_at_the_un_general_assembly.jpg', faces)
# Out:
# ERROR! Session/line number was not unique in database. History logging moved to new session 495
