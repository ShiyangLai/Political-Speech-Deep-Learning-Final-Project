# %%
# !pip install mtcnn
# Out:
# Collecting mtcnn
#   Downloading mtcnn-0.1.1-py3-none-any.whl (2.3 MB)
#      |████████████████████████████████| 2.3 MB 3.5 MB/s eta 0:00:01
# Collecting opencv-python>=4.1.0
#   Downloading opencv_python-4.5.5.64-cp36-abi3-macosx_10_15_x86_64.whl (46.3 MB)
#      |████████████████████████████████| 46.3 MB 19.0 MB/s eta 0:00:01     |██████████████████████▋         | 32.7 MB 14.8 MB/s eta 0:00:01
# Requirement already satisfied: keras>=2.0.0 in /Users/sudhamshu.hosamane/opt/anaconda3/envs/week-1/lib/python3.7/site-packages (from mtcnn) (2.8.0)
# Requirement already satisfied: numpy>=1.14.5 in /Users/sudhamshu.hosamane/opt/anaconda3/envs/week-1/lib/python3.7/site-packages (from opencv-python>=4.1.0->mtcnn) (1.21.5)
# Installing collected packages: opencv-python, mtcnn
# Successfully installed mtcnn-0.1.1 opencv-python-4.5.5.64

# %%
from mtcnn import MTCNN
import cv2

# %%
import matplotlib.pyplot as plt

# %%
img = cv2.cvtColor(cv2.imread("/Users/sudhamshu.hosamane/DataspellProjects/Political-Speech-Deep-Learning-Final-Project/dataset/images/1960-10-13_john_f._kennedy_debate_with_richard_nixon_in_new_york_and_los_angeles/246e557ab7.jpg"), cv2.COLOR_BGR2RGB)

# %%
plt.imshow(img)

# %%
detector = MTCNN()
# Out:
# ERROR! Session/line number was not unique in database. History logging moved to new session 449
# 2022-05-20 20:33:26.310080: I tensorflow/core/platform/cpu_feature_guard.cc:145] This TensorFlow binary is optimized with Intel(R) MKL-DNN to use the following CPU instructions in performance critical operations:  SSE4.1 SSE4.2
# To enable them in non-MKL-DNN operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-05-20 20:33:26.311660: I tensorflow/core/common_runtime/process_util.cc:115] Creating new thread pool with default inter op setting: 8. Tune using inter_op_parallelism_threads for best performance.

# %%
count_faces = lambda x: print(f'Num faces = {len(detector.detect_faces(x))}')

# %%
img = cv2.cvtColor(cv2.imread("/Users/sudhamshu.hosamane/DataspellProjects/Political-Speech-Deep-Learning-Final-Project/dataset/images/1790-01-08_george_washington_first_annual_message_to_congress/c689001057.jpg"), cv2.COLOR_BGR2RGB)

# %%
count_faces(img)
# Out:
# Num faces = 0

# %%
plt.imshow(img)
