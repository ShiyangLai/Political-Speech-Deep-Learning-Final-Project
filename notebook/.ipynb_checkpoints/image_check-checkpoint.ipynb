# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import math

# %%
image_embedding = pd.read_csv('../dataset/image_embeddings.csv', index_col=0)
image_embedding = image_embedding.set_index('President')

# %%
final_embedding = pd.read_csv('../dataset/final_embedding.csv', index_col=0)
final_embedding = pd.merge(final_embedding, image_embedding, how='inner', right_index=True, left_index=True)

# %%
from sklearn.manifold import TSNE
from sklearn.preprocessing import MinMaxScaler
tsneDoc = TSNE(n_components=2).fit_transform(image_embedding.values)
# Out:
# /Users/shiyang/.local/lib/python3.8/site-packages/sklearn/manifold/_t_sne.py:780: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# /Users/shiyang/.local/lib/python3.8/site-packages/sklearn/manifold/_t_sne.py:790: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   warnings.warn(

# %%
focal_presidents = ['George W. Bush', 'Barack Obama', 'Franklin D. Roosevelt', 'Bill Clinton', 'George H. W. Bush',
                    'Richard M. Nixon', 'John F. Kennedy', 'Lyndon B. Johnson', 'Jimmy Carter', 'Ronald Reagan']
df = pd.DataFrame(columns=['Name'])
for president in focal_presidents:
    dict_ = {}
    dict_['Name'] = president
    dict_['Appearance Uniquiality'] = np.mean([math.dist(image_embedding.loc[president], image_embedding.loc[president2])**2
                                  for president2 in focal_presidents if president2 != president])
    df = df.append(dict_, ignore_index=True)

# %%
scaler = MinMaxScaler((0.15, 0.85))
tsneDoc = TSNE(n_components=2).fit_transform(image_embedding.values)
sd_tsne = scaler.fit_transform(tsneDoc)
fig, axis = plt.subplots(1, 2, figsize=(16, 7), dpi=80)

x_axis_data = np.array([i for i in range(len(focal_presidents))])
x_axis_data_labels = list(map(lambda idx: focal_presidents[idx], x_axis_data))

axis[0].bar(x_axis_data, df['Appearance Uniquiality'].values, 0.5, align='center')
axis[0].grid()
axis[0].set_xticks(x_axis_data)
axis[0].set_xticklabels(x_axis_data_labels, rotation=90, fontsize=15)
axis[0].set_ylim([40, 90])
axis[0].tick_params(axis='both', which='major', labelsize=15)

for i in range(len(focal_presidents)):
    axis[1].scatter(sd_tsne[i, 0], sd_tsne[i, 1]+0.01, s=1e9 / df.loc[i, 'Appearance Uniquiality']**2.7, alpha=0.4)
    axis[1].text(x=sd_tsne[i, 0], y=sd_tsne[i, 1], s=focal_presidents[i], fontsize=15, ha='center', fontweight=500)
    axis[1].set_xlim([0, 1])
    axis[1].set_ylim([0, 1])
    axis[1].tick_params(axis='both', which='major', labelsize=15)
plt.show()
# Out:
# /Users/shiyang/.local/lib/python3.8/site-packages/sklearn/manifold/_t_sne.py:780: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# /Users/shiyang/.local/lib/python3.8/site-packages/sklearn/manifold/_t_sne.py:790: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   warnings.warn(

# %%
df.to_csv('../dataset/efficientnet_image_features.csv', index=False)

# %%
or_df = pd.read_csv('../dataset/final_dataset.csv', index_col=0)

# %%
or_df = pd.merge(or_df, df.set_index('Name'), how='inner', right_index=True, left_index=True)

# %%
or_df.to_csv('../dataset/final_dataset.csv')

# %%
final_embedding.to_csv('../dataset/final_embedding.csv')

# %%
# sudhamshu's implementation
df = pd.read_csv('../../image_emotion.csv', index_col=0)

# %%
df.dropna(subset=['emotion'], inplace=True)

# %%
# define emotion purity and
# Out:
#            Date              President       Party Context  \
# 515  1933-03-12  Franklin D. Roosevelt  Democratic   Money
# 516  1933-05-07  Franklin D. Roosevelt  Democratic   Money
# 517  1933-07-24  Franklin D. Roosevelt  Democratic   Money
# 518  1933-10-22  Franklin D. Roosevelt  Democratic   Money
# 519  1934-06-28  Franklin D. Roosevelt  Democratic   Money
# ..          ...                    ...         ...     ...
# 986  2018-09-25           Donald Trump  Republican      UN
# 987  2019-01-19           Donald Trump  Republican  Policy
# 989  2019-02-15           Donald Trump  Republican  Policy
# 990  2019-09-24           Donald Trump  Republican      UN
# 991  2019-09-25           Donald Trump  Republican   Press
#
#                                           Speech Title  \
# 515                              On the Banking Crisis
# 516            On Progress During the First Two Months
# 517            On the National Recovery Administration
# 518                               On Economic Progress
# 519                          On Addressing the Critics
# ..                                                 ...
# 986  Address at the 73rd Session of the United Nati...
# 987               Remarks about the US Southern Border
# 989              Speech Declaring a National Emergency
# 990     Remarks at the United Nations General Assembly
# 991                                   Press Conference
#
#                                                Summary  \
# 515  By the time of Roosevelt's inauguration, nearl...
# 516  Sixty days into the "First Hundred Days" Roose...
# 517  Roosevelt defends the New Deal at the end of t...
# 518  In the midst of discouraging economic news rep...
# 519  After summarizing the achievements of the seve...
# ..                                                 ...
# 986  President Donald Trump addresses the General A...
# 987  President Donald Trump speaks about what he se...
# 989  President Donald Trump declares a national eme...
# 990  President Donald Trump speaks to the 74th sess...
# 991  President Donald Trump holds a press conferenc...
#
#                                             Transcript  \
# 515  I want to talk for a few minutes with the peop...
# 516  On a Sunday night a week after my Inauguration...
# 517  After the adjournment of the historical specia...
# 518  It is three months since I have talked with th...
# 519  It has been several months since I have talked...
# ..                                                 ...
# 986  Madam President, Mr. Secretary-General, world ...
# 987  Just a short time ago, I had the honor of pres...
# 989  Thank you very much, everybody. Before we begi...
# 990  Thank you very much. Mr. President, Mr. Secret...
# 991  Thank you very much. Thank you. Well, thank yo...
#
#                                                    URL  \
# 515  https://millercenter.org/the-presidency/presid...
# 516  https://millercenter.org/the-presidency/presid...
# 517  https://millercenter.org/the-presidency/presid...
# 518  https://millercenter.org/the-presidency/presid...
# 519  https://millercenter.org/the-presidency/presid...
# ..                                                 ...
# 986  https://millercenter.org/the-presidency/presid...
# 987  https://millercenter.org/the-presidency/presid...
# 989  https://millercenter.org/the-presidency/presid...
# 990  https://millercenter.org/the-presidency/presid...
# 991  https://millercenter.org/the-presidency/presid...
#
#                                                    img  \
# 515  [[0.572549045085907, 0.5960784554481506, 0.662...
# 516  [[0.9529412388801575, 0.9529412388801575, 0.95...
# 517  [[0.10588236153125763, 0.40000003576278687, 0....
# 518  [[0.09019608050584793, 0.0470588281750679, 0.0...
# 519  [[0.4235294461250305, 0.4235294461250305, 0.42...
# ..                                                 ...
# 986  [[0.5215686559677124, 0.5215686559677124, 0.56...
# 987  [[0.29411765933036804, 0.3450980484485626, 0.3...
# 989  [[0.5568627715110779, 0.46274513006210327, 0.5...
# 990  [[0.729411780834198, 0.615686297416687, 0.6392...
# 991  [[0.2705882489681244, 0.2705882489681244, 0.27...
#
#                                              embedding emotion
# 515  [-0.2954917550086975, -0.35841402411460876, -0...   angry
# 516  [-0.2954917550086975, -0.3014950752258301, 0.7...     sad
# 517  [-0.2954917550086975, 0.16702881455421448, 0.4...   happy
# 518  [-0.2954917550086975, -0.35841402411460876, 0....     sad
# 519  [-0.2954917550086975, 0.13137003779411316, 0.6...     sad
# ..                                                 ...     ...
# 986  [-0.2954917550086975, -0.35841402411460876, 0....   angry
# 987  [-0.2954917550086975, -0.35841402411460876, 1....     sad
# 989  [-0.2954917550086975, 0.15529683232307434, 0.1...   angry
# 990  [-0.2954917550086975, 0.0413987934589386, 1.07...     sad
# 991  [-0.2954917550086975, 0.2320328652858734, 0.12...   angry
#
# [368 rows x 11 columns]
